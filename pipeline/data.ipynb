# %%
import pandas as pd

# %%
df = pd.read_csv("clean_data.csv")

df
# Out:
#      Unnamed: 0  amount_paid_usd         tags         country  \
# 0             0               55         Punk         Germany
# 1             1               63  Alternative           Italy
# 2             1               63  Psychedelic           Italy
# 3             2               63  Alternative           Italy
# 4             2               63  Psychedelic           Italy
# ..          ...              ...          ...             ...
# 335          64              189        Tekno  United Kingdom
# 336          64              189       Jungle  United Kingdom
# 337          64              189          DNB  United Kingdom
# 338          64              189   Electronic  United Kingdom
# 339          64              189    Breakcore  United Kingdom
#
#                            title                      artist  \
# 0            In the Name of Love  Die angepissten Turnbeutel
# 1    Amras - Infinite_Connection         Electricmoonrecords
# ...
