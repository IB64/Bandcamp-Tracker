# %%
import pandas as pd

# %%
df = pd.read_csv("clean_data.csv")

df
# Out:
#      amount_paid_usd          tags         country  \
# 0                164  Experimental          Greece
# 1                164     Psytrance          Greece
# 2                164     Sri Lanka          Greece
# 3                164   Psychedelic          Greece
# 4                657        Trance  United Kingdom
# ..               ...           ...             ...
# 190              219    Electronic           Japan
# 191              202     Melbourne  United Kingdom
# 192              700     Cape Town       Australia
# 193              700       Afropop       Australia
# 194              700           Pop       Australia
#
#                                   title          artist  \
# 0    HENTAICAMERAMAN & Simiantics - 419   Atman Records
# 1    HENTAICAMERAMAN & Simiantics - 419   Atman Records
# 2    HENTAICAMERAMAN & Simiantics - 419   Atman Records
# 3    HENTAICAMERAMAN & Simiantics - 419   Atman Records
# 4               Oprofessionell - Search  Oprofessionell
# ...
