# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

df['title'] = df['title'].str.strip()

df['amount_paid_usd'] = df['amount_paid_usd'] * 100
df['amount_paid_usd'] = df['amount_paid_usd'].astype(int)

df
# Out:
#     amount_paid_usd                                               tags  \
# 0               158  ['electronic', 'dub', 'jungle', 'jungle sounds...
# 1              1200  ['experimental', 'ambient', 'electronic', 'exp...
# 2               110  ['ebm', 'electronic', 'cyberpunk', 'dance', 'e...
# 3               189  ['bass', 'club', 'soca', 'uk bass', 'uk funky'...
# 4               100  ['alternative', 'coldwave', 'dance-punk', 'dar...
# 5               189  ['160 jungle', 'electronic', 'jungle', 'jungle...
# 6              2100                          ['alternative', 'Oxford']
# 7               219  ['160 bpm', '160bpm', 'ambient', 'down-tempo',...
# 8               110  ['atmospheric black metal', 'metal', 'christia...
# 9               125                           ['electronic', 'London']
# 10              100  ['crooner', 'folk', 'hope', 'jazz', 'meditatio...
# 11              100  ['experimental', 'eurorack', 'eurorack modular...
# ...
