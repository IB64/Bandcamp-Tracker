# %%
import pandas as pd

# %%
df = pd.read_csv("clean_data.csv")

df
# Out:
#      Unnamed: 0  amount_paid_usd         tags         country  \
# 0             0              657       Techno     Netherlands
# 1             0              657   Electronic     Netherlands
# 2             1              219        House  United Kingdom
# 3             1              219   Electronic  United Kingdom
# 4             1              219        Disco  United Kingdom
# ..          ...              ...          ...             ...
# 245          47              152   Electronic     Philippines
# 246          47              152  Underground     Philippines
# 247          47              152     Hypnotic     Philippines
# 248          47              152       Techno     Philippines
# 249          48              110        Other          France
#
#                                           title  \
# 0                           The Question Number
# 1                           The Question Number
# 2                Xumba Xumba (Eden Burns Remix)
# ...
