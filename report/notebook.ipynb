# %%
from os import environ
from datetime import datetime, timedelta

from dotenv import load_dotenv
from psycopg2 import extensions, connect
import pandas as pd
from xhtml2pdf import pisa

YESTERDAY_DATE = datetime.strftime(datetime.now() - timedelta(1), '%d-%m-%Y')


def get_db_connection() -> extensions.connection:
    """Returns a connection to the AWS Bandcamp database"""

    try:
        return connect(user=environ["DB_USER"],
                       password=environ["DB_PASSWORD"],
                       host=environ["DB_IP"],
                       port=environ["DB_PORT"],
                       database=environ["DB_NAME"])
    except ConnectionError:
        print("Error: Cannot connect to the database")

# %%
def load_all_data(db_connection: extensions.connection) -> pd.DataFrame:
    """Loads all the data from the database into a pandas dataframe"""

    with db_connection.cursor() as curr:

        curr.execute("""
                    SELECT sale_event.*, country.country, artist.artist_name, genre.genre, item_type.item_type, item.item_name
                    FROM sale_event
                    JOIN country
                    ON country.country_id = sale_event.country_id
                    JOIN item
                    ON item.item_id = sale_event.item_id
                    JOIN artist
                    ON artist.artist_id = item.artist_id
                    JOIN item_genre
                    ON item_genre.item_id = item.item_id
                    JOIN genre
                    ON genre.genre_id =item_genre.genre_id
                    JOIN item_type
                    ON item_type.item_type_id = item.item_type_id;""")
        tuples = curr.fetchall()
        column_names = ['sale_id', 'sale_time', 'amount', 'item_id',
                        'country_id', 'country', 'artist', 'genre', 'item_type', 'item_name']

        df = pd.DataFrame(tuples, columns=column_names)

        return df

# %%
def load_subscribers(db_connection: extensions.connection) -> pd.DataFrame:
    """Loads all the data from the database into a pandas dataframe"""

    with db_connection.cursor() as curr:

        curr.execute("""SELECT subscriber_email FROM subscribers;""")
        tuples = curr.fetchall()
        subscribers = []
        for tuple in tuples:
            subscribers.append(tuple[0])
        
        return subscribers

# %%
load_dotenv()
connection = get_db_connection()
data = load_all_data(connection)
subscribers =load_subscribers(connection)
subscribers
# Out:
# ['trainee.ishika.madhav@sigmalabs.co.uk',
#  'trainee.cai.thomas@sigmalabs.co.uk',
#  'trainee.angelo.beleno@sigmalabs.co.uk',
#  'trainee.caitlin.turnidge@sigmalabs.co.uk']

# %%
unique_sales = data.drop_duplicates(subset='sale_id', keep='first')
album_sales = unique_sales.drop(unique_sales[unique_sales['artist'] != 'we rob rave'].index)
album_sales
# Out:
#        sale_id                 sale_time  amount  item_id  country_id  \
# 50759     8002 2024-01-08 21:41:51+00:00     101    11608          25
#
#        country       artist genre item_type  \
# 50759  Hungary  we rob rave  juke     track
#
#                                 item_name
# 50759  WE ROB RAVE - BIRD UP (2023 REMIX)

# %%
unique_genre_count = data['genre'].value_counts().head(5).reset_index()
unique_genre_count
# Out:
#           genre  count
# 0   electronics  10072
# 1        techno   3903
# 2         house   2869
# 3       ambient   2112
# 4  experimental   1952

# %%
uunique_sales = data.drop_duplicates(subset='sale_id', keep='first')
album_sales = unique_sales.drop(unique_sales[unique_sales['item_type'] == 'track'].index)
popular_albums = album_sales['item_name'].value_counts().sort_values(ascending=False).head(
        5).reset_index()
popular_albums
# Out:
#             item_name  count
# 0  2024 Label Sampler     58
# 1          Archetypes     42
# 2                   C     36
# 3       Autumn Sun EP     24
# 4      Lander modules     23

# %%
unique_sales = data.drop_duplicates(subset='sale_id', keep='first')
album_sales = unique_sales.drop(
     unique_sales[unique_sales['item_type'] == 'track'].index)
album_sales = album_sales.groupby(
    'item_name')['amount'].sum()

album_sales = (
     album_sales/100).sort_values(ascending=False).head(5).reset_index()
album_sales
# Out:
#           item_name  amount
# 0  Beneath the Moss  400.00
# 1        Archetypes  287.33
# 2              DUCK  220.10
# 3  Oddiyana (24bit)  197.47
# 4    Letter To Self  170.79

# %%
country_sales = data['country'].value_counts(
).sort_values(ascending=False).reset_index()
country_sales
most_popular_artists = data.groupby('country')['artist'].apply(
    lambda x: x.value_counts().idxmax()).reset_index()
most_popular_artists
final = pd.merge(country_sales, most_popular_artists).head(10).to_dict('records')
final
# Out:
# [{'country': 'United States',
#   'count': 37197,
#   'artist': 'transcending obscurity records'},
#  {'country': 'United Kingdom', 'count': 13462, 'artist': 'various artists'},
#  {'country': 'Germany', 'count': 12835, 'artist': 'øl'},
#  {'country': 'Australia', 'count': 6098, 'artist': 'various artists'},
#  {'country': 'France', 'count': 5076, 'artist': 'air g'},
#  {'country': 'Canada', 'count': 4205, 'artist': 'radd'},
#  {'country': 'Japan', 'count': 3457, 'artist': 'kordhell'},
#  {'country': 'Netherlands', 'count': 1871, 'artist': 'abstract void'},
#  {'country': 'Switzerland', 'count': 1607, 'artist': 'various artists'},
#  {'country': 'Italy', 'count': 1553, 'artist': 'aleroj'}]

# %%
unique_sales = data.drop_duplicates(subset='sale_id', keep='first')

track_sales = unique_sales.drop(
    unique_sales[unique_sales['item_type'] == 'album'].index)
popular_tracks = track_sales['item_name'].value_counts().sort_values(ascending=False).head(
    5).reset_index()
selected = popular_tracks['item_name'].to_list()

track_sales = data[data['item_type'] == 'track']

filtered_track_sales = track_sales[track_sales['item_name'].isin(selected)]

track_genre = filtered_track_sales.groupby(['item_name'])[
    'genre'].agg(list).reset_index()

track_genre['genre'] = track_genre['genre'].apply(
    lambda x: list(set(x)))

final = pd.merge(popular_tracks, track_genre).to_dict('records')
track_sales
# Out:
#         sale_id                 sale_time  amount  item_id  country_id  \
# 120           1 2024-01-08 12:10:10+00:00     254       70          16
# 121           3 2024-01-08 12:10:22+00:00     100       71           3
# 122           3 2024-01-08 12:10:22+00:00     100       71           3
# 123           3 2024-01-08 12:10:22+00:00     100       71           3
# 124           3 2024-01-08 12:10:22+00:00     100       71           3
# ...         ...                       ...     ...      ...         ...
# 104637    18954 2024-01-09 11:44:58+00:00     164    19666           9
# 104638    18954 2024-01-09 11:44:58+00:00     164    19666           9
# 104639    18954 2024-01-09 11:44:58+00:00     164    19666           9
# 104640    18954 2024-01-09 11:44:58+00:00     164    19666           9
# 104641    18954 2024-01-09 11:44:58+00:00     164    19666           9
#
#             country              artist            genre item_type  \
# 120     Netherlands  anunaku & dj plead            other     track
# 121         Germany                 lon      electronics     track
# 122         Germany                 lon  brazilian music     track
# 123         Germany                 lon            indie     track
# 124         Germany                 lon            disco     track
# ...             ...                 ...              ...       ...
# 104637        Japan               cødex      electronics     track
# 104638        Japan               cødex           techno     track
# 104639        Japan               cødex          ambient     track
# 104640        Japan               cødex  hypnotic techno     track
# 104641        Japan               cødex         deeptech     track
#
#                                   item_name
# 120                                  Wheele
# 121     Marcos Valle - Estrelar (LON Remix)
# 122     Marcos Valle - Estrelar (LON Remix)
# 123     Marcos Valle - Estrelar (LON Remix)
# 124     Marcos Valle - Estrelar (LON Remix)
# ...                                     ...
# 104637                                Storm
# 104638                                Storm
# 104639                                Storm
# 104640                                Storm
# 104641                                Storm
#
# [47098 rows x 10 columns]

# %%
unique_sales = data.drop_duplicates(subset='sale_id', keep='first')
album_sales = unique_sales.drop(
    unique_sales[unique_sales['item_type'] == 'track'].index)
popular_albums = album_sales['item_name'].value_counts().sort_values(ascending=False).head(
    5).reset_index()
selected = popular_albums['item_name'].to_list()

album_sales = data[data['item_type'] == 'album']

filtered_album_sales = album_sales[album_sales['item_name'].isin(selected)]

albums_genre = filtered_album_sales.groupby(['item_name'])[
'genre'].agg(list).reset_index()

albums_genre['genre'] = albums_genre['genre'].apply(
lambda x: list(set(x))[:3])

albums_genre
# Out:
#             item_name                                              genre
# 0  2024 Label Sampler  [blackened death metal, brutal death metal, de...
# 1          Archetypes                     [synthwave, rock, electronics]
# 2       Autumn Sun EP                  [icelandic, electronics, electro]
# 3                   C                                      [electronics]
# 4      Lander modules            [downtempo, electronics, space ambient]
